# %%
#import library and read dataset
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv(r'C:\Users\simpo\Downloads\movies.csv')

# pd.set_option('display.max_rows', None)

# %%
#see dataset
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#look at the info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
# chage datatypes of score,vote budget gross
df['budget'] = df['budget'].astype('Int64')
df['gross'] = df['gross'].astype('Int64')

# %%
df['votes'] = df['votes'].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   Int64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   Int64
#  12  gross     7479 non-null   Int64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: Int64(3), float64(2), int64(1), object(9)
# memory usage: 921.2+ KB

# %%
# pd.set_option('display.max_rows', None)

# %%
# checking null value
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.rating
# Out:
# 0         R
# 1         R
# 2        PG
# 3        PG
# 4         R
#        ...
# 7663    NaN
# 7664    NaN
# 7665    NaN
# 7666    NaN
# 7667    NaN
# Name: rating, Length: 7668, dtype: object

# %%
# fill null value of rating column

df['rating'].fillna('Not Rated', inplace=True)

# %%
# fill null value of released column

# df.released
# df['released'].fillna('Unknow', inplace=True)
df['released'] = df['released'].fillna('Unknown')

# %%
# fill null value of vote column

# df['votes'].fillna(0,inplace=True )
df['votes'] = df['votes'].fillna(0)

# %%
# fill null value of score coulumn

# df['score'].fillna('0')
df['score'] = df['score'].fillna(0)

# %%
# fill null value of writer, star, country, budget, gross, company and runtime

df['writer'] = df['writer'].fillna('Unknow')
df['star'] = df['star'].fillna('Unknow')
df['country'] = df['country'].fillna('Unknow')
df['budget'] = df['budget'].fillna(0)
df['gross'] = df['gross'].fillna(0)
df['company'] = df['company'].fillna('Unknow')
df['runtime'] = df['runtime'].fillna(0)

# df['writer'].fillna('Unknow')
# df['star'].fillna('Unknow')
# df['country'].fillna('Unknow')
# df['budget'].fillna(0)
# df['gross'].fillna(0)
# df['company'].fillna('Unknow')
# df['runtime'].fillna(0)

# %%
#drop year columns for create exactly year

df = df.drop('year', axis=1)

# %%
# have some released year was not = year columns
# released  7666 non-null   object
df['year'] = df['released'].str.split(',').str[1].str.strip().str[:4]
df['year'] = df['year'].astype('Int64')

# %%
#scatter plot to see Budget vs Gross

plt.scatter(x=df['budget'],y=df['gross'],color='hotpink')
plt.title('Budget vs Gross')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sort dataframe by use gross value desc

df.sort_values(by=['gross'], ascending=False)
# Out:
#                                             name     rating    genre  \
# 5445                                      Avatar      PG-13   Action
# 7445                           Avengers: Endgame      PG-13   Action
# 3045                                     Titanic      PG-13    Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13   Action
# 7244                      Avengers: Infinity War      PG-13   Action
# ...                                          ...        ...      ...
# 1617                             Mortal Passions          R    Crime
# 1614                              Edge of Sanity          R   Horror
# 1606                                   I, Madman          R  Fantasy
# 1601                        My Twentieth Century  Not Rated   Comedy
# 7667                                   Tee em el  Not Rated   Horror
#
#                                released  score    votes        director  \
# ...

# %%
#regression plot 

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "pink"}, line_kws={"color": "blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#see correlation of dataframe and select only number type as int, float

number = df.select_dtypes(include=['number'])
number.corr(method='pearson')
#corr method pearson, kendall, spearman
# df.corr()
# Out:
#             score     votes    budget     gross   runtime      year
# score    1.000000  0.407101  0.056863  0.186012  0.394564  0.102744
# votes    0.407101  1.000000  0.486931  0.632870  0.306984  0.215582
# budget   0.056863  0.486931  1.000000  0.750157  0.268372  0.297674
# gross    0.186012  0.632870  0.750157  1.000000  0.244339  0.253253
# runtime  0.394564  0.306984  0.268372  0.244339  1.000000  0.117462
# year     0.102744  0.215582  0.297674  0.253253  0.117462  1.000000

# %%
#create heatmap from of correlation

matrix = number.corr(method='pearson')

sns.heatmap(matrix, annot=True)
plt.title('Correlation Matrix')

plt.xlabel('Movie Industry')
plt.ylabel('Movie Industry')
plt.show()

# %%
#change the columns that have datatype as a object to category and use cat.codes to generate number

df_toNum = df
for column in df_toNum:
    if(df_toNum[column].dtypes =='object'):
        df_toNum[column] = df_toNum[column].astype('category')
        df_toNum[column] = df_toNum[column].cat.codes
df_toNum.sort_values(by=['gross'], ascending=False)
# Out:
#       name  rating  genre  released  score    votes  director  writer  star  \
# 5445   533       5      0       696    7.8  1100000      1155    1778  2334
# 7445   535       5      0       183    8.4   903000       162     743  2241
# 3045  6896       5      6       704    7.8  1100000      1155    1778  1595
# 6663  5144       5      0       698    7.8   876000      1125    2550   524
# 7244   536       5      0       192    8.4   897000       162     743  2241
# ...    ...     ...    ...       ...    ...      ...       ...     ...   ...
# 1617  3712       6      5      1277    4.5      274       117      82  2798
# 1614  1745       6     10        55    5.2     1300      1033    1743   166
# 1606  2691       6      8       257    6.0     2900      2743     946  1195
# 1601  3836       3      4      1160    7.1     1500      1105    1696   681
# 7667  5394       3     10       391    5.7        7      2165    3344  2463
#
# ...

# %%
#create heatmap for all columns of dataset

all_matrix = df_toNum.corr(method='pearson')

sns.heatmap(matrix, annot=True)
plt.title('Correlation Matrix')

plt.xlabel('Movie Industry')
plt.ylabel('Movie Industry')
plt.show()

# %%
#see the correlation with unstack

matrix_all = df_toNum.corr()
pair = matrix_all.unstack()
pair
# Out:
# name  name        1.000000
#       rating     -0.010860
#       genre       0.016355
#       released   -0.010480
#       score       0.016377
#                     ...
# year  budget      0.297674
#       gross       0.253253
#       company    -0.020289
#       runtime     0.117462
#       year        1.000000
# Length: 225, dtype: float64

# %%
#sort correlation

sort = pair.sort_values()
sort
# Out:
# genre     budget     -0.334021
# budget    genre      -0.334021
# gross     genre      -0.234297
# genre     gross      -0.234297
#           votes      -0.145296
#                         ...
# released  released    1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# year      year        1.000000
# Length: 225, dtype: float64

# %%
#sort correlation with > than 5

high_corr = sort[(sort)>0.5]
high_corr
# Out:
# votes     gross       0.632870
# gross     votes       0.632870
#           budget      0.750157
# budget    gross       0.750157
# name      name        1.000000
# writer    writer      1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# year      year        1.000000
# dtype: float64
